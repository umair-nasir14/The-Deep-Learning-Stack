# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 20, 1000)

# %%
y = np.sin(x) + 0.2*x

# %%
plt.plot(x, y)

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x, y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot');

# %%
##SCATTER PLOT

X = np.random.randn(100, 2)
plt.scatter(X[:,0], X[:,1])

# %%
X = np.random.randn(200, 2)
X[:50] += 3
Y = np.zeros(200)
Y[:50] = 1
plt.scatter(X[:,0], X[:,1], c=Y)

# %%
X = np.random.randn(10000)

# %%
plt.hist(X);

# %%
plt.hist(X, bins = 50);

# %%
X = np.random.random(10000)
plt.hist(X, bins = 50);

# %%
# PLOTTING IMAGES

# !wget https://github.com/lazyprogrammer/machine_learning_examples/raw/master/cnn_class/lena.png
# Out:
# --2020-08-27 10:02:36--  https://github.com/lazyprogrammer/machine_learning_examples/raw/master/cnn_class/lena.png
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/cnn_class/lena.png [following]
# --2020-08-27 10:02:36--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/cnn_class/lena.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘lena.png’
#
# lena.png            100%[===================>] 462.73K  --.-KB/s    in 0.08s
#
# ...

# %%
import PIL as pl

# %%
im = pl.Image.open('lena.png')

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
arr = np.array(im)
arr.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(arr);

# %%
plt.imshow(im)

# %%
gray = arr.mean(axis=2)

# %%
gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(gray) #Heatmap done

# %%
plt.imshow(gray, cmap= 'gray')

# %%
a = np.random.uniform(-1, 1 , 1000)

# %%
a

# %%
a.shape
# Out:
# (1000,)

# %%
a.reshape(1000,1)

# %%
t = np.zeros(499)

# %%
Y = np.zeros(499)
Y[:200] = 1
plt.scatter(a[0:499,],a[500:999],c=Y)
